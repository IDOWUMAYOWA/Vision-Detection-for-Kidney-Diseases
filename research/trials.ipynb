# %%
## Download data from Google Drive
import gdown
url = "https://drive.google.com/file/d/131_QNNU40QBOuKmFE3o2f6guoIwMCYQm/view?usp=sharing"
output = "data.zip"
gdown.download(url, output)
# Out:
# /home/ims24/miniconda3/envs/kidneyVision/lib/python3.10/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=131_QNNU40QBOuKmFE3o2f6guoIwMCYQm
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/131_QNNU40QBOuKmFE3o2f6guoIwMCYQm/view?usp=sharing
# To: /home/ims24/Vision-Detection-for-Kidney-Diseases/research/data.zip
# 60.3kB [00:00, 36.9MB/s]
# 'data.zip'
